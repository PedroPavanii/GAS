# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: selenium in c:\users\pedro\anaconda3\lib\site-packages (4.8.3)
# Requirement already satisfied: trio~=0.17 in c:\users\pedro\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\pedro\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\pedro\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\pedro\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: sortedcontainers in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: sniffio in c:\users\pedro\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\pedro\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\pedro\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\pedro\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\pedro\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver-manager in c:\users\pedro\anaconda3\lib\site-packages (3.8.6)
# Requirement already satisfied: requests in c:\users\pedro\anaconda3\lib\site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: python-dotenv in c:\users\pedro\anaconda3\lib\site-packages (from webdriver-manager) (1.0.0)
# Requirement already satisfied: packaging in c:\users\pedro\anaconda3\lib\site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: tqdm in c:\users\pedro\anaconda3\lib\site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pedro\anaconda3\lib\site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pedro\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pedro\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pedro\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pedro\anaconda3\lib\site-packages (from requests->webdriver-manager) (2022.9.14)
# Requirement already satisfied: colorama in c:\users\pedro\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.5)

# %%
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service = service)

# %%
driver.get('https://portal.trt3.jus.br/internet/servicos/valores/salario-minimo')
url = driver.find_element(By.XPATH,'//*[@id="parent-fieldname-text"]/div/table')
html = url.get_attribute('outerHTML')
ts = pd.read_html(html)[0]
driver.quit()
# Out:
#          ANO/VIGÊNCIA                                              VALOR  \
# 0      2023 1º/1/2023  R$ 1.302,00 Por Mês R$ 43,40 Por Dia R$ 5,92 P...
# 1    - 2022 1º/1/2022  R$ 1.212,00 Por Mês R$ 40,40 Por Dia R$ 5,51 P...
# 2      2021 1º/1/2021  R$ 1.100,00 Por Mês R$ 36,67 Por Dia R$ 5,00 P...
# 3      2020 1º/2/2020  R$ 1.045,00 Por Mês R$ 34,83 Por Dia R$ 4,75 P...
# 4      2020 1º/1/2020  R$ 1.039,00 Por Mês R$ 34,63 Por Dia R$ 4,72 P...
# ..                ...                                                ...
# 129     1954 4/7/1954  Cr$ 2.200,00 Por Mês (valor regional para BH e...
# 130    1952 1º/1/1952  Cr$ 900,00 Por Mês Cr$ 30,00 Por Dia Cr$ 3,75 ...
# 131   1943 1º/12/1943  Cr$ 270,00 Por Mês Cr$ 10,80 Por Dia Cr$ 1,35 ...
# 132    1943 17/7/1943  Cr$ 212,00 Por Mês Cr$ 8,48 Por Dia Cr$ 1,06 P...
# 133     1940 4/7/1940  170$000 Por Mês 6$800 Por Dia $850 Por Hora (v...
#
#         MOEDA                                              FONTE
# 0        Real  MP n. 1.143, de 12/12/2022 DOU 12/12/2022 - Ed...
# 1        Real  MP n. 1.091, de 30/12/2021 DOU 31/12/2021 (Con...
# 2        Real  MP n. 1.021, de 30/12/2020 DOU 31/12/20 (Conve...
# 3        Real                MP n. 919, de 30/1/2020 DOU 31/1/20
# 4        Real  MP n. 916, de 31/12/2019 DOU 31/12/19 - Edição...
# ..        ...                                                ...
# 129  Cruzeiro          Decreto n.35.450, de 1º/5/1954 DOU 4/5/54
# 130  Cruzeiro       Decreto n.30.342, de 24/12/1951 DOU 26/12/51
# 131  Cruzeiro   Decreto-Lei n. 5.977, de 10/11/1943 DOU 22/11/43
# 132  Cruzeiro       Decreto-Lein.5.670, de 15/7/1943 DOU 17/7/43
# 133      Real  Decreto-Lein.2.162, de 1º/5/1940 DOU 4/5/40 (D...
#
# [134 rows x 4 columns]

# %%
# Out:
#        ANO/VIGÊNCIA                                              VALOR
# 0    2023 1º/1/2023  R$ 1.302,00 Por Mês R$ 43,40 Por Dia R$ 5,92 P...
# 1  - 2022 1º/1/2022  R$ 1.212,00 Por Mês R$ 40,40 Por Dia R$ 5,51 P...
# 2    2021 1º/1/2021  R$ 1.100,00 Por Mês R$ 36,67 Por Dia R$ 5,00 P...
# 3    2020 1º/2/2020  R$ 1.045,00 Por Mês R$ 34,83 Por Dia R$ 4,75 P...
# 4    2020 1º/1/2020  R$ 1.039,00 Por Mês R$ 34,63 Por Dia R$ 4,72 P...
